# %% [markdown]
# # Indian Premier League (IPL) Overview
#
# The **Indian Premier League (IPL)** is a professional Twenty20 cricket league in India that commenced in 2008. Over the years, it has evolved into one of the most popular and lucrative T20 tournaments globally.
#
# ## Key Points
#
# - **Teams:** Multiple franchises participate, including Mumbai Indians, Chennai Super Kings, Kolkata Knight Riders, and others.
# - **Format:** The league follows a round-robin format, leading to playoffs (Eliminator, Qualifier 1, Qualifier 2) and culminating in a final to determine the champion.
# - **Successive Champions:** Mumbai Indians and Chennai Super Kings stand out as the most successful teams, clinching multiple titles each.
# - **International Stars:** The IPL attracts top cricket talent from around the world, making it a high-octane and competitive tournament.
# - **Entertainment:** Renowned for its entertainment value, the IPL features elements such as cheerleaders, music, and a festive atmosphere alongside the intense cricket action.
# - **Individual Awards:** Players have the opportunity to win awards such as the Orange Cap for the leading run-scorer and the Purple Cap for the highest wicket-taker in a season.
#
# The IPL has significantly contributed to the global popularity of T20 cricket, establishing itself as an annual cricketing extravaganza eagerly anticipated by fans worldwide.

# %% [markdown]
# # About this Dataset :

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import colorama
from colorama import Fore, Back, Style

# %% [markdown]
# # Reading Datasets From Csv Files

# %%
Ball_Data_1= pd.read_csv('../data/IPL_Ball_by_Ball_2008_2022.csv')
Match_Data_2= pd.read_csv('../data/IPL_Matches_2008_2022.csv')

# %%
Ball_Data_1.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
Match_Data_2.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
# set Maximum options to display all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# hide all warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# show all columns of Ball_Data_1
print(f"The name of all columns in this datasets are as follows: {Ball_Data_1.columns}")
# Out:
# The name of all columns in this datasets are as follows: Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
# show all columns of Match_Data_2
print(f"The name of all columns in this datasets are as follows: {Match_Data_2.columns}")
# Out:
# The name of all columns in this datasets are as follows: Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %% [markdown]
# # Data Info of Ball Data

# %%
# data info of Ball_Data_1
Ball_Data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 225954 non-null  int64
#  1   innings            225954 non-null  int64
#  2   overs              225954 non-null  int64
#  3   ballnumber         225954 non-null  int64
#  4   batter             225954 non-null  object
#  5   bowler             225954 non-null  object
#  6   non-striker        225954 non-null  object
#  7   extra_type         12049 non-null   object
#  8   batsman_run        225954 non-null  int64
#  9   extras_run         225954 non-null  int64
#  10  total_run          225954 non-null  int64
#  11  non_boundary       225954 non-null  int64
#  12  isWicketDelivery   225954 non-null  int64
#  13  player_out         11151 non-null   object
#  14  kind               11151 non-null   object
# ...

# %% [markdown]
# # Data Info of Match Data

# %%
# data info Match_Data_2
Match_Data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# describe Ball_Data_1
Ball_Data_1.describe()
# Out:
#                  ID        innings          overs     ballnumber  \
# count  2.259540e+05  225954.000000  225954.000000  225954.000000
# mean   8.320470e+05       1.483868       9.185679       3.619750
# std    3.379542e+05       0.503104       5.681797       1.810633
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.012620e+05       1.000000       4.000000       2.000000
# 50%    8.297370e+05       1.000000       9.000000       4.000000
# 75%    1.178395e+06       2.000000      14.000000       5.000000
# max    1.312200e+06       6.000000      19.000000      10.000000
#
#          batsman_run     extras_run     total_run   non_boundary  \
# count  225954.000000  225954.000000  225954.00000  225954.000000
# mean        1.243523       0.066907       1.31043       0.000093
# std         1.618166       0.341470       1.60605       0.009640
# min         0.000000       0.000000       0.00000       0.000000
# ...

# %% [markdown]
# <a id="3"></a>
# # <div style="text-align: left; background-color: #147eb0;  color: white; padding: 14px; line-height: 0.5;"> 🗄️ Exploratory Data Analysis </div>

# %% [markdown]
# <a id="4.2"></a>
# ### <div style="text-align: left; background-color: #58a9db;  color: white; padding: 14px; line-height: 0.5;"> 🏏Batsmen Data Analysis</div>

# %% [markdown]
# # Top Run Scorer in IPL

# %%
# Top run-scorers
top_run_scorers = Ball_Data_1.groupby('batter')['batsman_run'].sum().sort_values(ascending=False).head(10)
print("Top Run Scorers in IPL:")
print(top_run_scorers)
# Out:
# Top Run Scorers in IPL:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %%
# Plotting the bar graph with value annotations
plt.figure(figsize=(10, 6))
bars = top_run_scorers.plot(kind='bar', color='blue')

# Add value annotations on top of each bar
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, round(yval, 2), ha='center', va='bottom', fontsize=8)

plt.title('Top Run Scorers in IPL')
plt.xlabel('Batter')
plt.ylabel('Individual Score in a Match')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # Top Batter with with most Player of the Match

# %%
# Count the occurrences of each player in the 'Player_of_Match' column
top_batters = Match_Data_2['Player_of_Match'].value_counts().head(10)

# Display the result
print("Top batters with most 'Player_of_Match' awards:")
print(top_batters.head(10))  # Displaying the top 10 batters
# Out:
# Top batters with most 'Player_of_Match' awards:
# Player_of_Match
# AB de Villiers    25
# CH Gayle          22
# DA Warner         18
# RG Sharma         18
# MS Dhoni          17
# YK Pathan         16
# SR Watson         16
# KA Pollard        14
# SK Raina          14
# V Kohli           14
# Name: count, dtype: int64

# %%
# Plotting the bar graph
plt.figure(figsize=(10, 6))
top_batters.plot(kind='bar', color='orange')
plt.title('Most Player of the Match Awards')
plt.xlabel('Batter')
plt.ylabel('Individual Score in a Match')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # Batters With Highest Individual Score

# %%
# Highest individual score
highest_individual_score = Ball_Data_1.groupby(['ID', 'batter'])['batsman_run'].sum().reset_index()
highest_individual_score = highest_individual_score.groupby('batter')['batsman_run'].max().sort_values(ascending=False).head(10)
print("Top 10 Batsmen with the Highest Individual Score in a Match:")
print(highest_individual_score)
# Out:
# Top 10 Batsmen with the Highest Individual Score in a Match:
# batter
# CH Gayle          175
# BB McCullum       158
# Q de Kock         140
# AB de Villiers    133
# KL Rahul          132
# RR Pant           128
# M Vijay           127
# DA Warner         126
# JC Buttler        124
# V Sehwag          122
# Name: batsman_run, dtype: int64

# %%
# Highest individual score
highest_individual_score = Ball_Data_1.groupby(['ID', 'batter'])['batsman_run'].sum().reset_index()
highest_individual_score = highest_individual_score.groupby('batter')['batsman_run'].max().sort_values(ascending=False).head(10)

# Plotting the bar graph
plt.figure(figsize=(10, 6))
highest_individual_score.plot(kind='bar', color='orange')
plt.title('Top 10 Batsmen with Highest Individual Score in a Match')
plt.xlabel('Batsmen')
plt.ylabel('Individual Score in a Match')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # Top 10 Batsmen With the Most Centuries and Fifties in IPL

# %%
# Centuries scored
centuries_scored = Ball_Data_1.groupby(['ID', 'batter'])['batsman_run'].sum().reset_index()
centuries_scored = centuries_scored[centuries_scored['batsman_run'] >= 100]

# Counting the number of centuries scored by each batsman
centuries_count = centuries_scored['batter'].value_counts().head(10)

print("Top 10 Batsmen with the Most Centuries in IPL:")
print(centuries_count)

# Half-centuries scored (Fifties)
fifties_scored = Ball_Data_1.groupby(['ID', 'batter'])['batsman_run'].sum().reset_index()
fifties_scored = fifties_scored[(fifties_scored['batsman_run'] >= 50) & (fifties_scored['batsman_run'] < 100)]

# Counting the number of fifties scored by each batsman
fifties_count = fifties_scored['batter'].value_counts().head(10)

print("\nTop 10 Batsmen with the Most Fifties in IPL:")
print(fifties_count)
# Out:
# Top 10 Batsmen with the Most Centuries in IPL:
# batter
# CH Gayle          6
# V Kohli           5
# JC Buttler        5
# SR Watson         4
# DA Warner         4
# KL Rahul          4
# SV Samson         3
# AB de Villiers    3
# HM Amla           2
# BA Stokes         2
# Name: count, dtype: int64
#
# Top 10 Batsmen with the Most Fifties in IPL:
# batter
# DA Warner         55
# S Dhawan          47
# V Kohli           45
# AB de Villiers    41
# RG Sharma         40
# SK Raina          39
# G Gambhir         36
# CH Gayle          32
# KL Rahul          31
# AM Rahane         28
# Name: count, dtype: int64

# %%
# Centuries scored
centuries_scored = Ball_Data_1.groupby(['ID', 'batter'])['batsman_run'].sum().reset_index()
centuries_scored = centuries_scored[centuries_scored['batsman_run'] >= 100]
centuries_count = centuries_scored['batter'].value_counts().head(10)

# Plotting bar graph for centuries
plt.figure(figsize=(10, 5))
centuries_count.plot(kind='bar', color='gold')
plt.title('Top 10 Batsmen with the Most Centuries in IPL')
plt.xlabel('Batsmen')
plt.ylabel('Number of Centuries')
plt.xticks(rotation=45, ha='right')
plt.show()

# Half-centuries scored (Fifties)
fifties_scored = Ball_Data_1.groupby(['ID', 'batter'])['batsman_run'].sum().reset_index()
fifties_scored = fifties_scored[(fifties_scored['batsman_run'] >= 50) & (fifties_scored['batsman_run'] < 100)]
fifties_count = fifties_scored['batter'].value_counts().head(10)

# Plotting bar graph for fifties
plt.figure(figsize=(10, 5))
fifties_count.plot(kind='bar', color='lightblue')
plt.title('Top 10 Batsmen with the Most Fifties in IPL')
plt.xlabel('Batsmen')
plt.ylabel('Number of Fifties')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # Top 10 Batsmen with Highest Strike Rate

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with the specified columns
# Replace the 'df' with the actual name of your DataFrame

# Calculate the total runs and total balls faced by each batsman
batsman_stats = Ball_Data_1.groupby('batter').agg({'batsman_run': 'sum', 'ID': 'count'})

# Filter batsmen with more than 200 runs
qualified_batsmen = batsman_stats[batsman_stats['batsman_run'] >= 200]

# Calculate the strike rate for qualified batsmen
qualified_batsmen['strike_rate'] = (qualified_batsmen['batsman_run'] / qualified_batsmen['ID']) * 100

# Sort batsmen by strike rate in descending order and select the top 10
top_10_batsmen = qualified_batsmen.sort_values(by='strike_rate', ascending=False).head(10)

# Display the top 10 batsmen with the highest strike rate
print("Top 10 Batsmen with the Highest Strike Rate (Minimum 200 Runs):")
print(top_10_batsmen[['strike_rate', 'batsman_run']])
# Out:
# Top 10 Batsmen with the Highest Strike Rate (Minimum 200 Runs):
#                 strike_rate  batsman_run
# batter
# AD Russell       168.234323         2039
# BCJ Cutting      163.013699          238
# JM Sharma        157.046980          234
# LS Livingstone   155.965909          549
# SP Narine        154.367470         1025
# PBB Rajapaksa    150.364964          206
# CH Morris        149.636804          618
# V Sehwag         148.827059         2728
# AB de Villiers   148.580442         5181
# GJ Maxwell       147.676639         2320

# %%
import seaborn as sns

# Set seaborn style for a different look
sns.set(style="whitegrid")

# Plot the horizontal bar graph with a different color palette
plt.figure(figsize=(12, 8))
sns.barplot(x=top_10_batsmen['strike_rate'], y=top_10_batsmen.index, palette='viridis')  # Use a different color palette

plt.xlabel('Strike Rate')
plt.ylabel('Batsmen')
plt.title('Top 10 Batsmen with Highest Strike Rate (Min 200 Runs)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Top Batsmen with Most Sixes

# %%
# Merge ball-by-ball data with match data using 'ID' column
merged_data = pd.merge(Ball_Data_1, Match_Data_2, on='ID')

# Filter rows where batsmen made sixes (batsman_run = 6)
sixes_data = merged_data[merged_data['batsman_run'] == 6]

# Count the number of sixes hit by each batsman
batsman_sixes_count = sixes_data['batter'].value_counts()

# Get the top batsmen with the most sixes
top_six_hitters = batsman_sixes_count.nlargest(10)

# Display the results
print("Top Batsmen with Most Sixes:")
print(top_six_hitters)
# Out:
# Top Batsmen with Most Sixes:
# batter
# CH Gayle          359
# AB de Villiers    253
# RG Sharma         241
# MS Dhoni          229
# KA Pollard        224
# V Kohli           219
# DA Warner         216
# SK Raina          204
# SR Watson         190
# RV Uthappa        182
# Name: count, dtype: int64

# %% [markdown]
# # Top Batsmen with Most Fours

# %%
# Merge ball-by-ball data with match data using 'ID' column
merged_data = pd.merge(Ball_Data_1, Match_Data_2, on='ID')

# Filter rows where batsmen made fours (batsman_run = 4)
fours_data = merged_data[merged_data['batsman_run'] == 4]

# Count the number of fours hit by each batsman
batsman_fours_count = fours_data['batter'].value_counts()

# Get the top batsmen with the most fours
top_four_hitters = batsman_fours_count.nlargest(10)

# Display the results
print("Top Batsmen with Most Fours:")
print(top_four_hitters)
# Out:
# Top Batsmen with Most Fours:
# batter
# S Dhawan          701
# V Kohli           581
# DA Warner         577
# RG Sharma         519
# SK Raina          506
# G Gambhir         492
# RV Uthappa        481
# AM Rahane         431
# KD Karthik        426
# AB de Villiers    414
# Name: count, dtype: int64

# %%
# Merge ball-by-ball data with match data using 'ID' column for both sixes and fours
merged_data_sixes = pd.merge(Ball_Data_1, Match_Data_2, on='ID')
merged_data_fours = pd.merge(Ball_Data_1, Match_Data_2, on='ID')

# Filter rows where batsmen made sixes (batsman_run = 6)
sixes_data = merged_data_sixes[merged_data_sixes['batsman_run'] == 6]

# Count the number of sixes hit by each batsman
batsman_sixes_count = sixes_data['batter'].value_counts()
top_six_hitters = batsman_sixes_count.nlargest(10)

# Plotting bar graph for top batsmen with most sixes
plt.figure(figsize=(10, 5))
top_six_hitters.plot(kind='bar', color='orange')
plt.title('Top Batsmen with Most Sixes')
plt.xlabel('Batsmen')
plt.ylabel('Number of Sixes')
plt.xticks(rotation=45, ha='right')
plt.show()

# Filter rows where batsmen made fours (batsman_run = 4)
fours_data = merged_data_fours[merged_data_fours['batsman_run'] == 4]

# Count the number of fours hit by each batsman
batsman_fours_count = fours_data['batter'].value_counts()
top_four_hitters = batsman_fours_count.nlargest(10)

# Plotting bar graph for top batsmen with most fours
plt.figure(figsize=(10, 5))
top_four_hitters.plot(kind='bar', color='green')
plt.title('Top Batsmen with Most Fours')
plt.xlabel('Batsmen')
plt.ylabel('Number of Fours')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# <a id="4.2"></a>
# ### <div style="text-align: left; background-color: #58a9db;  color: white; padding: 14px; line-height: 0.5;"> 🏏Bowler Data Analysis</div>

# %% [markdown]
# # Top 10 wicket takers

# %%
# top 10 wicket takers
print(Back.GREEN+ Style.BRIGHT+'Top 10 wicket takers'+ Style.RESET_ALL)
dismissal_list = ['caught','caught and bowled','bowled','stumped','hit wicket']
# %pip install Jinja2
top10_bowlers=Ball_Data_1[(Ball_Data_1['isWicketDelivery']==1) & (Ball_Data_1['kind'].isin(dismissal_list))]\
                            .groupby('bowler').agg(wicket_count=('isWicketDelivery', 'count'))\
                            .sort_values('wicket_count', ascending=False).reset_index().head(10)
top10_bowlers.style.background_gradient("Blues")
plt.figure(figsize=(10, 6))
plt.bar(top10_bowlers['bowler'], top10_bowlers['wicket_count'], color='green')
plt.xlabel('Bowler')
plt.ylabel('Number of Wickets')
plt.title('Top 10 Wicket-Takers')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()

# Display the graph
plt.show()
# Out:
# Top 10 wicket takers
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Bowler performance (wicket count) against opponent teams

# %%
# Bowler performance (wicket count) against opponent teams

print(Back.GREEN + Style.BRIGHT + 'Bowler performance (wicket count) against opponent teams' + Style.RESET_ALL)

bowler_team = Ball_Data_1[(Ball_Data_1['isWicketDelivery'] == 1) & (Ball_Data_1['kind'].isin(dismissal_list)) \
                          & (Ball_Data_1['bowler'].isin(top10_bowlers['bowler']))] \
    .groupby(['bowler', 'BattingTeam']).agg(wkt_count=('isWicketDelivery', 'count')) \
    .reset_index()

# Pivot the table for better visualization
bowler_team_pivot = bowler_team.pivot_table('wkt_count', ['BattingTeam'], 'bowler')

# Plotting the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(bowler_team_pivot, cmap='Greens', annot=True, fmt='g', linewidths=.5)
plt.title('Bowler Performance (Wicket Count) Against Opponent Teams')
plt.xlabel('Bowler')
plt.ylabel('Opponent Team')

# Display the graph
plt.show()
# Out:
# Bowler performance (wicket count) against opponent teams

# %% [markdown]
# <a id="3"></a>
# # <div style="text-align: left; background-color: #147eb0;  color: white; padding: 14px; line-height: 0.5;"> 🗄️Data Preparation for Partnership Analysis </div>

# %%
#Let us add new derived features to the ball_data Dataframe...
Ball_Data_1['bowlingteam'] = ''
Ball_Data_1['first_batter'] = ''
Ball_Data_1['second_batter'] = ''

# %%
#In ball_data, we have two types of rows, which are to be treated as same for computing the partnership
#batter        non-striker
#-------------------------
#YBK Jaiswal   JC Buttler
#JC Buttler    YBK Jaiswal

#So we will be creating two new features as below and use them from partnership calculation
#first_batter second_batter
#--------------------------
#JC Buttler    YBK Jaiswal
#JC Buttler    YBK Jaiswal

Ball_Data_1['first_batter']  = Ball_Data_1.apply(lambda x: x['batter'] if x['batter']  <  x['non-striker'] else x['non-striker'], axis=1)
Ball_Data_1['second_batter'] = Ball_Data_1.apply(lambda x: x['non-striker'] if x['batter']  <  x['non-striker'] else x['batter'], axis=1)

# %%
# #In ball_data,we have battingteam feature, let us add bowlingteam fature
# #Let us add season info too..

# Merge datasets using the correct column names
Ball_Data_1 = pd.merge(Ball_Data_1, Match_Data_2[['ID', 'Team1', 'Team2', 'Season']], how='left', on='ID')
Ball_Data_1['BowlingTeam'] = Ball_Data_1.apply(lambda x: x['Team2'] if x['BattingTeam'] == x['Team1'] else x['Team1'], axis=1)

# %%
# Correct the code to add 'win_against' feature
Match_Data_2['win_against'] = Match_Data_2.apply(lambda x: x['Team2'] if x['WinningTeam'] == x['Team1'] else x['Team1'], axis=1)

# %% [markdown]
# <a id="4.2"></a>
# ### <div style="text-align: left; background-color: #58a9db;  color: white; padding: 14px; line-height: 0.5;"> Partnership Performance</div>

# %% [markdown]
# # Top Ten Partnership

# %%
import plotly.express as px
import plotly.graph_objects as go

partnership_data = Ball_Data_1.groupby(['ID', 'Season', 'first_batter', 'second_batter', 'BattingTeam', 'BowlingTeam']) \
                             .agg(partnership=('total_run', 'sum')).reset_index()

top10_partnerships = partnership_data.sort_values(by='partnership', ascending=False).head(10)
top10_partnerships = top10_partnerships.sort_values(by='partnership', ascending=True)

colorsy = px.colors.qualitative.Plotly

fig = go.Figure(data=px.bar(x=top10_partnerships.BattingTeam,
                            y=top10_partnerships.partnership,
                            color=top10_partnerships.first_batter + ' & ' + top10_partnerships.second_batter,
                            color_discrete_sequence=colorsy,
                            title='<b>Top 10 Partnerships in IPL</b>',
                            text=top10_partnerships.partnership,
                            height=500))

fig.update_layout(
    font_family="Courier New",
    title_font_family="Times New Roman",
    title_font_color="red",
    title_font_size=20,
    xaxis_title="<b>Batting Team</b>",
    yaxis_title="<b>Partnership</b>",
    legend_title_font_color="green"
)

fig.show()

# %% [markdown]
# <a id="4.2"></a>
# ### <div style="text-align: left; background-color: #58a9db;  color: white; padding: 14px; line-height: 0.5;"> 	Data Analysis of Teams</div>

# %% [markdown]
# # Total matches played by each team

# %%
#Total matches played by each team:

# Combine Team1 and Team2 from Match_Data_2 to get a list of all teams
all_teams = pd.concat([Match_Data_2['Team1'], Match_Data_2['Team2']])

# Calculate the total matches played by each team
matches_played = all_teams.value_counts()

# Display the result
print("Total matches played by each team:")
print(matches_played)
# Out:
# Total matches played by each team:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# Name: count, dtype: int64

# %%
# Combine Team1 and Team2 from Match_Data_2 to get a list of all teams
all_teams = pd.concat([Match_Data_2['Team1'], Match_Data_2['Team2']])

# Calculate the total matches played by each team
matches_played = all_teams.value_counts()

# Set seaborn style for a different look
sns.set(style="whitegrid")

# Plotting the horizontal bar graph with a different color palette
plt.figure(figsize=(12, 8))
sns.barplot(x=matches_played.values, y=matches_played.index, palette='viridis')  # Use a different color palette

plt.title('Total Matches Played by Each Team', fontsize=16)
plt.xlabel('Total Matches Played', fontsize=14)
plt.ylabel('Team', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)

plt.show()

# %% [markdown]
# # Win Ratio of Each Team

# %%
# Calculate the total matches played by each team
all_teams = pd.concat([Match_Data_2['Team1'], Match_Data_2['Team2']])
matches_played = all_teams.value_counts()

# Calculate the total wins for each team
wins = Match_Data_2['WinningTeam'].value_counts()

# Create a DataFrame to store the results
team_stats = pd.DataFrame({
    'MatchesPlayed': matches_played,
    'Wins': wins,
})

# Fill NaN values with 0 (for teams that haven't won any matches)
team_stats = team_stats.fillna(0)

# Calculate the win ratio
team_stats['WinRatio'] = team_stats['Wins'] / team_stats['MatchesPlayed']

# Display the result
print("Win ratio of each team:")
print(team_stats[['MatchesPlayed', 'Wins', 'WinRatio']])
# Out:
# Win ratio of each team:
#                              MatchesPlayed  Wins  WinRatio
# Chennai Super Kings                    208   121  0.581731
# Deccan Chargers                         75    29  0.386667
# Delhi Capitals                          63    36  0.571429
# Delhi Daredevils                       161    67  0.416149
# Gujarat Lions                           30    13  0.433333
# Gujarat Titans                          16    12  0.750000
# Kings XI Punjab                        190    88  0.463158
# Kochi Tuskers Kerala                    14     6  0.428571
# Kolkata Knight Riders                  223   114  0.511211
# Lucknow Super Giants                    15     9  0.600000
# Mumbai Indians                         231   131  0.567100
# Pune Warriors                           46    12  0.260870
# Punjab Kings                            28    13  0.464286
# Rajasthan Royals                       192    96  0.500000
# ...

# %%
# Calculate the total matches played by each team
all_teams = pd.concat([Match_Data_2['Team1'], Match_Data_2['Team2']])
matches_played = all_teams.value_counts()

# Calculate the total wins for each team
wins = Match_Data_2['WinningTeam'].value_counts()

# Create a DataFrame to store the results
team_stats = pd.DataFrame({
    'MatchesPlayed': matches_played,
    'Wins': wins,
})

# Fill NaN values with 0 (for teams that haven't won any matches)
team_stats = team_stats.fillna(0)

# Calculate the win ratio
team_stats['WinRatio'] = team_stats['Wins'] / team_stats['MatchesPlayed']

# Plotting the bar chart
plt.figure(figsize=(12, 6))
team_stats['WinRatio'].plot(kind='bar', color='lightgreen')
plt.title('Win Ratio of Each Team')
plt.xlabel('Team')
plt.ylabel('Win Ratio')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# <a id="4.5"></a>
# ### <div style="text-align: left; background-color: #58a9db;  color: white; padding: 14px; line-height: 0.5;"> High scores chased</div>

# %% [markdown]
# # Top 5 Team High Scores Successfully Chased

# %%
import pandas as pd
import matplotlib.pyplot as plt
from colorama import Back, Fore, Style

# Assuming you have a DataFrame named 'match_scores' with the specified columns
# Replace 'match_scores' with the actual name of your DataFrame

# Select chased matches and sort by first_inning score in descending order
chased_matches = match_scores[match_scores['WonBy'] == 'Wickets'].sort_values('first_inning', ascending=False).head()

# Print header
print(Back.GREEN + Style.BRIGHT + 'Top 5 High scores successfully chased:' + Style.RESET_ALL)

# Print details and create a bar chart with values inside the bars
plt.figure(figsize=(10, 6))
colors = ['skyblue', 'salmon', 'lightgreen', 'gold', 'lightcoral']
for i, (idx, row) in enumerate(chased_matches.iterrows()):
    print(
        Fore.RED + Style.BRIGHT + row['Team2'] + Style.RESET_ALL +
        ' successfully chased target of ' +
        Back.CYAN + Style.BRIGHT + str(row['first_inning']) + Style.RESET_ALL +
        ' against ' +
        Fore.RED + Style.BRIGHT + row['Team1'] + Style.RESET_ALL +
        ' in season ' +
        Fore.BLUE + Style.BRIGHT + row['Season'] + Style.RESET_ALL
    )
    plt.bar(i, row['first_inning'], color=colors[i])
    plt.text(i, row['first_inning'], str(row['first_inning']), ha='center', va='bottom')

# Customize the chart
plt.title('Top 5 High Scores Successfully Chased')
plt.xlabel('Team - Season')
plt.ylabel('Score Chased')
plt.xticks(range(len(chased_matches)), chased_matches['Team2'] + ' - ' + chased_matches['Season'], rotation=45, ha='right')
plt.tight_layout()

# Display the graph
plt.show()
# Out:
# Top 5 High scores successfully chased:
# Rajasthan Royals successfully chased target of 223.0 against Kings XI Punjab in season 2020/21
# Mumbai Indians successfully chased target of 218.0 against Chennai Super Kings in season 2021
# Rajasthan Royals successfully chased target of 214.0 against Deccan Chargers in season 2007/08
# Lucknow Super Giants successfully chased target of 210.0 against Chennai Super Kings in season 2022
# Gujarat Lions successfully chased target of 208.0 against Delhi Daredevils in season 2017
